# %% [markdown]
# # Домашнее задание №7 по математической статистике

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('hotel_bookings.csv')
pd.set_option('display.max_columns', None)

# %%
df.sample(5)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 110259    City Hotel            0        343               2017
# 37582   Resort Hotel            0        339               2017
# 113849    City Hotel            0        147               2017
# 49586     City Hotel            0        113               2016
# 36864   Resort Hotel            0        310               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 110259              April                        16
# 37582                June                        24
# 113849               June                        24
# 49586               April                        16
# 36864                 May                        20
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 110259                         21                        2
# 37582                          16                        2
# 113849                         11                        2
# 49586                          15                        0
# 36864                          18                        4
#
#         stays_in_week_nights  adults  children  babies meal country  \
# 110259                     2       2       1.0       0   BB     ITA
# 37582                      5       2       0.0       0   HB     FRA
# 113849                     0       2       0.0       0   HB     DEU
# 49586                      2       2       0.0       0   BB     FRA
# 36864                     10       2       0.0       0   BB     GBR
#
#        market_segment distribution_channel  is_repeated_guest  \
# 110259         Direct               Direct                  0
# 37582       Online TA                TA/TO                  0
# 113849      Online TA                TA/TO                  0
# 49586       Online TA                TA/TO                  0
# 36864   Offline TA/TO                TA/TO                  0
#
#         previous_cancellations  previous_bookings_not_canceled  \
# 110259                       0                               0
# 37582                        0                               0
# 113849                       0                               0
# 49586                        0                               0
# 36864                        0                               0
#
#        reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 110259                  G                  G                1   No Deposit
# 37582                   E                  E                0   No Deposit
# 113849                  A                  A                0   No Deposit
# 49586                   A                  A                0   No Deposit
# 36864                   D                  E                1   No Deposit
#
#         agent  company  days_in_waiting_list customer_type    adr  \
# 110259    NaN      NaN                     0     Transient  213.3
# 37582   240.0      NaN                     0     Transient  130.5
# 113849    9.0      NaN                     0     Transient  180.0
# 49586     9.0      NaN                     0     Transient   96.3
# 36864   243.0      NaN                     0      Contract   80.4
#
#         required_car_parking_spaces  total_of_special_requests  \
# 110259                            0                          2
# 37582                             1                          1
# 113849                            0                          1
# 49586                             0                          1
# 36864                             0                          0
#
#        reservation_status reservation_status_date
# 110259          Check-Out              2017-04-25
# 37582           Check-Out              2017-06-23
# 113849          Check-Out              2017-06-13
# 49586           Check-Out              2016-04-17
# 36864           Check-Out              2017-06-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_week_nights         adults  \
# count            119390.000000         119390.000000  119390.000000
# mean                  0.927599              2.500302       1.856403
# std                   0.998613              1.908286       0.579261
# min                   0.000000              0.000000       0.000000
# 25%                   0.000000              1.000000       2.000000
# 50%                   1.000000              2.000000       2.000000
# 75%                   2.000000              3.000000       2.000000
# max                  19.000000             50.000000      55.000000
#
#             children         babies  is_repeated_guest  \
# count  119386.000000  119390.000000      119390.000000
# mean        0.103890       0.007949           0.031912
# std         0.398561       0.097436           0.175767
# min         0.000000       0.000000           0.000000
# 25%         0.000000       0.000000           0.000000
# 50%         0.000000       0.000000           0.000000
# 75%         0.000000       0.000000           0.000000
# max        10.000000      10.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           119390.000000                   119390.000000
# mean                 0.087118                        0.137097
# std                  0.844336                        1.497437
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes          agent      company  days_in_waiting_list  \
# count    119390.000000  103050.000000  6797.000000         119390.000000
# mean          0.221124      86.693382   189.266735              2.321149
# std           0.652306     110.774548   131.655015             17.594721
# min           0.000000       1.000000     6.000000              0.000000
# 25%           0.000000       9.000000    62.000000              0.000000
# 50%           0.000000      14.000000   179.000000              0.000000
# 75%           0.000000     229.000000   270.000000              0.000000
# max          21.000000     535.000000   543.000000            391.000000
#
#                  adr  required_car_parking_spaces  total_of_special_requests
# count  119390.000000                119390.000000              119390.000000
# mean      101.831122                     0.062518                   0.571363
# std        50.535790                     0.245291                   0.792798
# min        -6.380000                     0.000000                   0.000000
# 25%        69.290000                     0.000000                   0.000000
# 50%        94.575000                     0.000000                   0.000000
# 75%       126.000000                     0.000000                   1.000000
# max      5400.000000                     8.000000                   5.000000

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# top      No Deposit     Transient          Check-Out              2015-10-21
# freq         104641         89613              75166                    1461

# %% [markdown]
# **Вопрос 1**
# Из какого города прибывает наибольшее количество гостей (по данным обоих отелей суммарно)?
# Дайте ответ названием страны из трех больших букв, также, как указано в данных

# %%
df.country.value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# MRT        1
# NPL        1
# UMI        1
# CYM        1
# NIC        1
# Name: country, Length: 177, dtype: int64

# %% [markdown]
# Ответ: 'PRT'

# %% [markdown]
# **Вопрос 2**
# Какая цена за одну ночь в каждом из отелей?
#
# Ответ необходимо дать вне зависимости от типа номера, включенного питания. Также обратите внимание, что платящими пользователями мы считаем только взрослых и детей, младенцев необходимо исключить из расчета.
#
# Ответ необходимо дать в формате в одну строку: Resort Hotel: 00.00, City Hotel: 00.00
# - цену необходимо указать с точностью до двух знаков после запятой
# - разделение долей может быть через точку или запятую
# - наименования отелей в указанном формате, двоеточие и запятая обязательны для автоматического расчета ответа

# %%
# Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights

# %%
df['avg_adr'] = df.adr / (df.adults + df.children)  #/ (df.stays_in_weekend_nights + df.stays_in_week_nights)

# %%
df[['hotel', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'adr', 'avg_adr']].sample(10)
# Out:
#               hotel  stays_in_weekend_nights  stays_in_week_nights  adults  \
# 65508    City Hotel                        0                     3       2
# 79129    City Hotel                        1                     2       2
# 12265  Resort Hotel                        0                     4       3
# 72698    City Hotel                        0                     3       1
# 33873  Resort Hotel                        1                     5       2
# 98188    City Hotel                        1                     4       2
# 44923    City Hotel                        0                     1       2
# 57461    City Hotel                        1                     2       2
# 94424    City Hotel                        2                     3       2
# 48677    City Hotel                        2                     2       3
#
#        children     adr     avg_adr
# 65508       2.0  230.00   57.500000
# 79129       0.0  100.80   50.400000
# 12265       1.0  164.00   41.000000
# 72698       0.0  130.50  130.500000
# 33873       0.0   47.50   23.750000
# 98188       0.0   78.00   39.000000
# 44923       0.0   70.00   35.000000
# 57461       0.0  105.00   52.500000
# 94424       0.0   90.95   45.475000
# 48677       0.0  179.50   59.833333

# %%
df.query("adults == 0 & children == 0 & babies == 0 & adr > 0")\
        [['hotel', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'adr', 'avg_adr']]
# Out:
#                hotel  stays_in_weekend_nights  stays_in_week_nights  adults  \
# 31765   Resort Hotel                        2                     8       0
# 47444     City Hotel                        2                     4       0
# 50701     City Hotel                        2                     4       0
# 50702     City Hotel                        2                     4       0
# 55809     City Hotel                        3                     5       0
# 78586     City Hotel                        1                     2       0
# 85931     City Hotel                        2                     6       0
# 88439     City Hotel                        2                     4       0
# 92814     City Hotel                        2                     5       0
# 92962     City Hotel                        2                     0       0
# 94769     City Hotel                        2                     2       0
# 95544     City Hotel                        0                     4       0
# 96648     City Hotel                        3                     6       0
# 98492     City Hotel                        4                     9       0
# 101399    City Hotel                        0                     2       0
# 101401    City Hotel                        1                     3       0
# 101794    City Hotel                       16                    41       0
# 101957    City Hotel                        1                     3       0
# 102008    City Hotel                        1                     2       0
# 102185    City Hotel                        4                     7       0
# 103714    City Hotel                        0                     3       0
# 104145    City Hotel                        2                     5       0
# 104516    City Hotel                        4                    10       0
# 106562    City Hotel                        5                    10       0
# 106833    City Hotel                        0                     3       0
# 107594    City Hotel                        4                     7       0
# 111406    City Hotel                        0                     1       0
# 114583    City Hotel                        1                     4       0
# 115029    City Hotel                        0                     3       0
# 116251    City Hotel                        1                     1       0
# 116534    City Hotel                        2                     5       0
#
#         children     adr  avg_adr
# 31765        0.0   28.00      inf
# 47444        0.0   56.27      inf
# 50701        0.0   50.87      inf
# 50702        0.0   50.87      inf
# 55809        0.0   57.30      inf
# 78586        0.0    6.00      inf
# 85931        0.0    3.38      inf
# 88439        0.0  136.46      inf
# 92814        0.0   77.53      inf
# 92962        0.0    1.00      inf
# 94769        0.0   69.50      inf
# 95544        0.0   32.85      inf
# 96648        0.0   89.20      inf
# 98492        0.0   16.92      inf
# 101399       0.0  165.38      inf
# 101401       0.0  168.30      inf
# 101794       0.0    8.34      inf
# 101957       0.0   97.40      inf
# 102008       0.0   92.67      inf
# 102185       0.0    6.40      inf
# 103714       0.0   20.88      inf
# 104145       0.0    1.29      inf
# 104516       0.0   27.69      inf
# 106562       0.0   35.81      inf
# 106833       0.0   86.40      inf
# 107594       0.0    8.00      inf
# 111406       0.0  200.00      inf
# 114583       0.0   90.00      inf
# 115029       0.0  100.80      inf
# 116251       0.0   73.80      inf
# 116534       0.0   22.86      inf

# %%
df[df.adr > 0][['avg_adr']].describe()
# groupby('hotel').avg_adr.agg('mean')
# Out:
#           avg_adr
# count  117426.000
# mean          inf
# std           NaN
# min         0.130
# 25%        37.500
# 50%        49.895
# 75%        66.600
# max           inf

# %%
df[(df.is_canceled == 0) & (df.hotel == 'Resort Hotel')].adr.mean()\
        / (df[(df.is_canceled == 0) & (df.hotel == 'Resort Hotel')].adults 
           + df[(df.is_canceled == 0) & (df.hotel == 'Resort Hotel')].children
          ).mean()
# Out:
# 46.8324075295471

# %%
df[(df.is_canceled == 0) & (df.hotel == 'City Hotel')].adr.mean()\
        / (df[(df.is_canceled == 0) & (df.hotel == 'City Hotel')].adults 
           + df[(df.is_canceled == 0) & (df.hotel == 'City Hotel')].children
          ).mean()
# Out:
# 54.84722758279929

# %%
df[(df.adr > 0) & (df.reservation_status == 'Canceled')].sample(10)
# (df.adr > 0) &  (df.reservation_status == 'Canceled') & (df.reservation_status != 'Check-Out')
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 73179    City Hotel            1         13               2017
# 75885    City Hotel            1        351               2015
# 4620   Resort Hotel            1         77               2016
# 72059    City Hotel            1        336               2017
# 69642    City Hotel            1        348               2017
# 61084    City Hotel            1        190               2016
# 51687    City Hotel            1        158               2016
# 63974    City Hotel            1         10               2017
# 52679    City Hotel            1        337               2016
# 11979  Resort Hotel            1        257               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 73179             August                        33                         16
# 75885            October                        40                          3
# 4620               March                        13                         24
# 72059               July                        29                         19
# 69642               June                        22                          3
# 61084           December                        49                          1
# 51687                May                        22                         24
# 63974           February                         8                         25
# 52679               June                        24                          9
# 11979               June                        23                          6
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 73179                        0                     2       2       0.0
# 75885                        2                     2       2       0.0
# 4620                         0                     3       2       0.0
# 72059                        0                     2       2       0.0
# 69642                        2                     1       2       0.0
# 61084                        2                     3       2       0.0
# 51687                        0                     2       1       0.0
# 63974                        1                     1       3       0.0
# 52679                        0                     2       2       0.0
# 11979                        6                    15       2       0.0
#
#        babies meal country market_segment distribution_channel  \
# 73179       0   BB     PRT         Direct               Direct
# 75885       0   BB     PRT         Groups                TA/TO
# 4620        0   HB     PRT  Offline TA/TO                TA/TO
# 72059       0   BB     ITA      Online TA                TA/TO
# 69642       0   BB     PRT  Offline TA/TO                TA/TO
# 61084       0   BB     PRT  Offline TA/TO                TA/TO
# 51687       0   BB     PRT         Groups                TA/TO
# 63974       0   BB     GBR      Online TA                TA/TO
# 52679       0   BB     PRT         Groups                TA/TO
# 11979       0   BB     PRT      Online TA                TA/TO
#
#        is_repeated_guest  previous_cancellations  \
# 73179                  0                       0
# 75885                  0                       1
# 4620                   0                       0
# 72059                  0                       0
# 69642                  0                       0
# 61084                  0                       0
# 51687                  0                       0
# 63974                  0                       0
# 52679                  0                       0
# 11979                  0                       0
#
#        previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 73179                               0                  A                  A
# 75885                               0                  A                  A
# 4620                                0                  A                  A
# 72059                               0                  A                  A
# 69642                               0                  A                  A
# 61084                               0                  A                  A
# 51687                               0                  A                  A
# 63974                               0                  D                  D
# 52679                               0                  A                  A
# 11979                               0                  D                  D
#
#        booking_changes deposit_type  agent  company  days_in_waiting_list  \
# 73179                0   No Deposit    NaN      NaN                     0
# 75885                0   No Deposit    1.0      NaN                     0
# 4620                 0   No Deposit  314.0      NaN                     0
# 72059                0   No Deposit    9.0      NaN                     0
# 69642                0   Non Refund    6.0      NaN                     0
# 61084                0   No Deposit   83.0      NaN                     0
# 51687                0   Non Refund   37.0      NaN                    31
# 63974                0   No Deposit    9.0      NaN                     0
# 52679                0   Non Refund    1.0      NaN                     0
# 11979                0   No Deposit  242.0      NaN                     0
#
#          customer_type     adr  required_car_parking_spaces  \
# 73179        Transient  160.00                            0
# 75885  Transient-Party   62.00                            0
# 4620         Transient   70.80                            0
# 72059        Transient   99.90                            0
# 69642        Transient   90.00                            0
# 61084        Transient   59.16                            0
# 51687        Transient  130.00                            0
# 63974        Transient  163.00                            0
# 52679        Transient   62.00                            0
# 11979        Transient   93.60                            0
#
#        total_of_special_requests reservation_status reservation_status_date
# 73179                          0           Canceled              2017-08-10
# 75885                          0           Canceled              2015-07-06
# 4620                           1           Canceled              2016-03-14
# 72059                          0           Canceled              2016-08-23
# 69642                          0           Canceled              2017-05-16
# 61084                          0           Canceled              2016-11-28
# 51687                          0           Canceled              2016-01-18
# 63974                          0           Canceled              2017-02-15
# 52679                          0           Canceled              2015-10-21
# 11979                          1           Canceled              2016-10-03

# %%
# Чувилина сказала считать так, вроде
df[(df.adr > 0) & (df.hotel == 'Resort Hotel')].adr.sum()\
        / (df[(df.adr > 0) & (df.hotel == 'Resort Hotel')].adults 
           + df[(df.adr > 0) & (df.hotel == 'Resort Hotel')].children
          ).sum()
# (df.reservation_status != 'Canceled')???
# Out:
# 48.574502802998374

# %%
df[(df.adr > 0) & (df.hotel == 'City Hotel')].adr.sum()\
        / (df[(df.adr > 0) & (df.hotel == 'City Hotel')].adults 
           + df[(df.adr > 0) & (df.hotel == 'City Hotel')].children
          ).sum()
# Out:
# 54.79772276448362

# %% [markdown]
# Ответ: Resort Hotel: 48.57, City Hotel: 54.80

# %%
df[(df.adr > 0) & (df.hotel == 'Resort Hotel') & (df.reservation_status != 'Canceled')].adr.sum()\
        / (df[(df.adr > 0) & (df.hotel == 'Resort Hotel') & (df.reservation_status != 'Canceled')].adults 
           + df[(df.adr > 0) & (df.hotel == 'Resort Hotel') & (df.reservation_status != 'Canceled')].children
          ).sum()
# Out:
# 47.75778472459956

# %%
df[(df.adr > 0) & (df.hotel == 'City Hotel') & (df.reservation_status != 'Canceled')].adr.sum()\
        / (df[(df.adr > 0) & (df.hotel == 'City Hotel') & (df.reservation_status != 'Canceled')].adults 
           + df[(df.adr > 0) & (df.hotel == 'City Hotel') & (df.reservation_status != 'Canceled')].children
          ).sum()
# Out:
# 55.82907784726426

# %% [markdown]
# Ответ2: Resort Hotel: 47.76, City Hotel: 55.83

# %%
df[(df.is_canceled == 1) & (df.reservation_status != 'Canceled') & (df.reservation_status != 'No-Show')]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []

# %% [markdown]
# **Вопрос 3**
# В какой сезон в обоих отелях меньше всего посетителей?
# Необходимо дать текстовый ответ по примеру (начиная со строчной буквы): весна, зима, лето или осень

# %%
df.arrival_date_month.value_counts()
# Out:
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64

# %%
df[df.adr > 0].arrival_date_month.value_counts()
# Out:
# August       13711
# July         12491
# May          11611
# April        10953
# October      10929
# June         10819
# September    10351
# March         9641
# February      7921
# November      6641
# December      6561
# January       5801
# Name: arrival_date_month, dtype: int64

# %%
df[df.is_canceled == 0].arrival_date_month.value_counts()
# Out:
# August       8638
# July         7919
# May          7114
# October      6914
# March        6645
# April        6565
# June         6404
# September    6392
# February     5372
# November     4672
# December     4409
# January      4122
# Name: arrival_date_month, dtype: int64

# %%
df['people'] = df[['adults', 'children', 'babies']].sum(axis=1)
df.people
# Out:
# 0         2.0
# 1         2.0
# 2         1.0
# 3         1.0
# 4         2.0
#          ...
# 119385    2.0
# 119386    3.0
# 119387    2.0
# 119388    2.0
# 119389    2.0
# Name: people, Length: 119390, dtype: float64

# %%
df[df.is_canceled == 0].groupby('arrival_date_month').people.agg('sum').sort_values()
# Out:
# arrival_date_month
# January       7186.0
# November      8017.0
# December      8492.0
# February     10029.0
# September    12068.0
# March        12245.0
# June         12520.0
# October      12720.0
# April        12833.0
# May          13442.0
# July         17317.0
# August       19138.0
# Name: people, dtype: float64

# %%
df.groupby('arrival_date_month').people.agg('sum').sort_values()
# Out:
# arrival_date_month
# January      10524.0
# November     11812.0
# December     13196.0
# February     15299.0
# March        18432.0
# September    20366.0
# October      21044.0
# June         21481.0
# April        22000.0
# May          22456.0
# July         27607.0
# August       30771.0
# Name: people, dtype: float64

# %%
df[df.reservation_status != 'Canceled'].groupby('arrival_date_month').people.agg('sum').sort_values()
# Out:
# arrival_date_month
# January       7312.0
# November      8140.0
# December      8655.0
# February     10368.0
# September    12195.0
# March        12453.0
# June         12685.0
# October      12852.0
# April        12974.0
# May          13671.0
# July         17534.0
# August       19326.0
# Name: people, dtype: float64

# %% [markdown]
# Ответ: зима

# %%
df['stays_in_nights'] = df[df.is_canceled == 0].stays_in_weekend_nights + df[df.is_canceled == 0].stays_in_week_nights

# %%
df.groupby('arrival_date_month').agg({'stays_in_nights': 'mean'})
# Out:
#                     stays_in_nights
# arrival_date_month
# April                      3.319878
# August                     3.911669
# December                   3.022000
# February                   2.938943
# January                    2.749151
# July                       3.903523
# June                       3.614304
# March                      3.282318
# May                        3.319651
# November                   3.153896
# October                    3.157940
# September                  3.591677

# %% [markdown]
# **Вопрос 4**
# Сколько ночей максимум остаются посетители в отеле Resort Hotel?

# %%
df[(df.hotel == 'Resort Hotel') & (df.stays_in_week_nights > 40) & (df.reservation_status != 'Canceled')]
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 14037  Resort Hotel            0        113               2015
# 14038  Resort Hotel            0        126               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14037             August                        31                          1
# 14038               July                        28                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 14037                       18                    42       1       0.0
# 14038                       19                    50       1       0.0
#
#        babies meal country market_segment distribution_channel  \
# 14037       0   HB     NaN         Direct               Direct
# 14038       0   HB     NaN         Direct               Direct
#
#        is_repeated_guest  previous_cancellations  \
# 14037                  0                       0
# 14038                  0                       0
#
#        previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 14037                               0                  E                  E
# 14038                               1                  E                  E
#
#        booking_changes deposit_type  agent  company  days_in_waiting_list  \
# 14037                0   No Deposit    NaN      NaN                     0
# 14038                2   No Deposit    NaN      NaN                     0
#
#       customer_type    adr  required_car_parking_spaces  \
# 14037     Transient  110.5                            0
# 14038     Transient  110.0                            0
#
#        total_of_special_requests reservation_status reservation_status_date
# 14037                          3          Check-Out              2015-09-30
# 14038                          3          Check-Out              2016-09-12

# %%
df[(df.hotel == 'Resort Hotel') & (df.reservation_status != 'Canceled')][['stays_in_weekend_nights', 'stays_in_week_nights']].sum(axis=1).max()
# Out:
# 69

# %% [markdown]
# Ответ: 69

# %% [markdown]
# **Вопрос 5**
# Сколько ночей максимум остаются посетители в отеле City Hotel?

# %%
df[(df.hotel == 'City Hotel') & (df.stays_in_week_nights > 25)]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 54704   City Hotel            0        206               2016
# 88017   City Hotel            0         16               2016
# 101794  City Hotel            0        140               2016
# 106561  City Hotel            0         11               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 54704                July                        30
# 88017               March                        11
# 101794          September                        39
# 106561            January                         3
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 54704                          23                       14
# 88017                          11                       14
# 101794                         22                       16
# 106561                         15                       13
#
#         stays_in_week_nights  adults  children  babies meal country  \
# 54704                     34       2       0.0       0   SC     PRT
# 88017                     35       0       0.0       0   BB     PRT
# 101794                    41       0       0.0       0   SC     GBR
# 106561                    30       0       0.0       0   SC     USA
#
#        market_segment distribution_channel  is_repeated_guest  \
# 54704       Online TA                TA/TO                  0
# 88017       Corporate                TA/TO                  0
# 101794      Online TA                TA/TO                  0
# 106561      Online TA                TA/TO                  0
#
#         previous_cancellations  previous_bookings_not_canceled  \
# 54704                        0                               0
# 88017                        0                               0
# 101794                       0                               0
# 106561                       0                               0
#
#        reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 54704                   A                  K                6   No Deposit
# 88017                   A                  K               21   No Deposit
# 101794                  A                  K               12   No Deposit
# 106561                  A                  K               14   No Deposit
#
#         agent  company  days_in_waiting_list    customer_type   adr  \
# 54704     9.0      NaN                     0  Transient-Party  0.00
# 88017     NaN    215.0                     0  Transient-Party  0.00
# 101794    9.0      NaN                     0        Transient  8.34
# 106561    9.0      NaN                     0        Transient  0.00
#
#         required_car_parking_spaces  total_of_special_requests  \
# 54704                             0                          1
# 88017                             0                          0
# 101794                            0                          2
# 106561                            0                          0
#
#        reservation_status reservation_status_date
# 54704           Check-Out              2016-09-09
# 88017           Check-Out              2016-04-29
# 101794          Check-Out              2016-11-18
# 106561          Check-Out              2017-02-27

# %%
df[(df.hotel == 'City Hotel') & (df.reservation_status != 'Canceled')][['stays_in_weekend_nights', 'stays_in_week_nights']].sum(axis=1).max()
# Out:
# 57

# %% [markdown]
# Ответ: 57

# %% [markdown]
# **Вопрос 6**
# Какой процент бронирований происходит online? (Online TA).
# Ответ необходимо дать с точностью до одного знака.

# %%
df.market_segment.value_counts(normalize=True) * 100
# Out:
# Online TA        47.304632
# Offline TA/TO    20.285619
# Groups           16.593517
# Direct           10.558673
# Corporate         4.435045
# Complementary     0.622330
# Aviation          0.198509
# Undefined         0.001675
# Name: market_segment, dtype: float64

# %% [markdown]
# Ответ: 47.3

# %% [markdown]
# **Вопрос 7**
# Какой процент отмен бронирований в отеле Resort Hotel?
# Ответ необходимо дать целым числом.

# %%
# Чувилина сказала по reservation_status
df[df.hotel == 'Resort Hotel'].reservation_status.value_counts(normalize=True) * 100
# Out:
# Check-Out    72.236645
# Canceled     27.036945
# No-Show       0.726410
# Name: reservation_status, dtype: float64

# %%
df[df.hotel == 'Resort Hotel'].is_canceled.value_counts(normalize=True) * 100
# канселед в этом столбце = канселед + ноу шоу в reservation_status
# Out:
# 0    72.236645
# 1    27.763355
# Name: is_canceled, dtype: float64

# %% [markdown]
# Ответ: 27?

# %% [markdown]
# **Вопрос 8**
# В какой сезон самое большое количество отмен в Resort Hotel?
# Необходимо дать текстовый ответ: весна, зима, лето или осень

# %%
df[(df.is_canceled == 1) & (df.hotel == 'Resort Hotel')]\
        .groupby('arrival_date_month')\
        .agg('count')\
        .sort_values('is_canceled', ascending=False)
# Out:
#                     hotel  is_canceled  lead_time  arrival_date_year  \
# arrival_date_month
# August               1637         1637       1637               1637
# July                 1436         1436       1436               1436
# April                1059         1059       1059               1059
# May                  1024         1024       1024               1024
# June                 1007         1007       1007               1007
# September            1006         1006       1006               1006
# October               978          978        978                978
# February              795          795        795                795
# March                 763          763        763                763
# December              631          631        631                631
# November              461          461        461                461
# January               325          325        325                325
#
#                     arrival_date_week_number  arrival_date_day_of_month  \
# arrival_date_month
# August                                  1637                       1637
# July                                    1436                       1436
# April                                   1059                       1059
# May                                     1024                       1024
# June                                    1007                       1007
# September                               1006                       1006
# October                                  978                        978
# February                                 795                        795
# March                                    763                        763
# December                                 631                        631
# November                                 461                        461
# January                                  325                        325
#
#                     stays_in_weekend_nights  stays_in_week_nights  adults  \
# arrival_date_month
# August                                 1637                  1637    1637
# July                                   1436                  1436    1436
# April                                  1059                  1059    1059
# May                                    1024                  1024    1024
# June                                   1007                  1007    1007
# September                              1006                  1006    1006
# October                                 978                   978     978
# February                                795                   795     795
# March                                   763                   763     763
# December                                631                   631     631
# November                                461                   461     461
# January                                 325                   325     325
#
#                     children  babies  meal  country  market_segment  \
# arrival_date_month
# August                  1637    1637  1637     1636            1637
# July                    1436    1436  1436     1430            1436
# April                   1059    1059  1059     1051            1059
# May                     1024    1024  1024     1024            1024
# June                    1007    1007  1007     1006            1007
# September               1006    1006  1006      990            1006
# October                  978     978   978      974             978
# February                 795     795   795      794             795
# March                    763     763   763      762             763
# December                 631     631   631      626             631
# November                 461     461   461      460             461
# January                  325     325   325      324             325
#
#                     distribution_channel  is_repeated_guest  \
# arrival_date_month
# August                              1637               1637
# July                                1436               1436
# April                               1059               1059
# May                                 1024               1024
# June                                1007               1007
# September                           1006               1006
# October                              978                978
# February                             795                795
# March                                763                763
# December                             631                631
# November                             461                461
# January                              325                325
#
#                     previous_cancellations  previous_bookings_not_canceled  \
# arrival_date_month
# August                                1637                            1637
# July                                  1436                            1436
# April                                 1059                            1059
# May                                   1024                            1024
# June                                  1007                            1007
# September                             1006                            1006
# October                                978                             978
# February                               795                             795
# March                                  763                             763
# December                               631                             631
# November                               461                             461
# January                                325                             325
#
#                     reserved_room_type  assigned_room_type  booking_changes  \
# arrival_date_month
# August                            1637                1637             1637
# July                              1436                1436             1436
# April                             1059                1059             1059
# May                               1024                1024             1024
# June                              1007                1007             1007
# September                         1006                1006             1006
# October                            978                 978              978
# February                           795                 795              795
# March                              763                 763              763
# December                           631                 631              631
# November                           461                 461              461
# January                            325                 325              325
#
#                     deposit_type  agent  company  days_in_waiting_list  \
# arrival_date_month
# August                      1637   1538        8                  1637
# July                        1436   1323       24                  1436
# April                       1059    926       36                  1059
# May                         1024    860       40                  1024
# June                        1007    905       14                  1007
# September                   1006    831      104                  1006
# October                      978    770       27                   978
# February                     795    663       44                   795
# March                        763    665       39                   763
# December                     631    531       20                   631
# November                     461    417       32                   461
# January                      325    272       19                   325
#
#                     customer_type   adr  required_car_parking_spaces  \
# arrival_date_month
# August                       1637  1637                         1637
# July                         1436  1436                         1436
# April                        1059  1059                         1059
# May                          1024  1024                         1024
# June                         1007  1007                         1007
# September                    1006  1006                         1006
# October                       978   978                          978
# February                      795   795                          795
# March                         763   763                          763
# December                      631   631                          631
# November                      461   461                          461
# January                       325   325                          325
#
#                     total_of_special_requests  reservation_status  \
# arrival_date_month
# August                                   1637                1637
# July                                     1436                1436
# April                                    1059                1059
# May                                      1024                1024
# June                                     1007                1007
# September                                1006                1006
# October                                   978                 978
# February                                  795                 795
# March                                     763                 763
# December                                  631                 631
# November                                  461                 461
# January                                   325                 325
#
#                     reservation_status_date
# arrival_date_month
# August                                 1637
# July                                   1436
# April                                  1059
# May                                    1024
# June                                   1007
# September                              1006
# October                                 978
# February                                795
# March                                   763
# December                                631
# November                                461
# January                                 325

# %%
df[(df.reservation_status == 'Canceled') & (df.hotel == 'Resort Hotel')]\
        .groupby('arrival_date_month')\
        .agg('count')\
        .sort_values('is_canceled', ascending=False)
# Out:
#                     hotel  is_canceled  lead_time  arrival_date_year  \
# arrival_date_month
# August               1614         1614       1614               1614
# July                 1415         1415       1415               1415
# April                1045         1045       1045               1045
# September             995          995        995                995
# May                   993          993        993                993
# June                  987          987        987                987
# October               956          956        956                956
# February              756          756        756                756
# March                 729          729        729                729
# December              594          594        594                594
# November              441          441        441                441
# January               306          306        306                306
#
#                     arrival_date_week_number  arrival_date_day_of_month  \
# arrival_date_month
# August                                  1614                       1614
# July                                    1415                       1415
# April                                   1045                       1045
# September                                995                        995
# May                                      993                        993
# June                                     987                        987
# October                                  956                        956
# February                                 756                        756
# March                                    729                        729
# December                                 594                        594
# November                                 441                        441
# January                                  306                        306
#
#                     stays_in_weekend_nights  stays_in_week_nights  adults  \
# arrival_date_month
# August                                 1614                  1614    1614
# July                                   1415                  1415    1415
# June                                4366               4366
# October                             4337               4337
# September                           4290               4290
# March                               4072               4072
# April                               4015               4015
# February                            3064               3064
# November                            2696               2696
# December                            2392               2392
# January                             2254               2254
#
#                     previous_cancellations  previous_bookings_not_canceled  \
# arrival_date_month
# August                                5381                            5381
# July                                  4782                            4782
# May                                   4579                            4579
# June                                  4366                            4366
# October                               4337                            4337
# September                             4290                            4290
# March                                 4072                            4072
# April                                 4015                            4015
# February                              3064                            3064
# November                              2696                            2696
# December                              2392                            2392
# January                               2254                            2254
#
#                     reserved_room_type  assigned_room_type  booking_changes  \
# arrival_date_month
# August                            5381                5381             5381
# July                              4782                4782             4782
# May                               4579                4579             4579
# June                              4366                4366             4366
# October                           4337                4337             4337
# September                         4290                4290             4290
# March                             4072                4072             4072
# April                             4015                4015             4015
# February                          3064                3064             3064
# November                          2696                2696             2696
# December                          2392                2392             2392
# January                           2254                2254             2254
#
#                     deposit_type  agent  company  days_in_waiting_list  \
# arrival_date_month
# August                      5381   4847      186                  5381
# July                        4782   4415      183                  4782
# May                         4579   4017      369                  4579
# June                        4366   3965      225                  4366
# October                     4337   3925      240                  4337
# September                   4290   3827      204                  4290
# March                       4072   3570      246                  4072
# April                       4015   3643      184                  4015
# February                    3064   2432      359                  3064
# November                    2696   2232      312                  2696
# December                    2392   2015      175                  2392
# January                     2254   1818      222                  2254
#
#                     customer_type   adr  required_car_parking_spaces  \
# arrival_date_month
# August                       5381  5381                         5381
# July                         4782  4782                         4782
# May                          4579  4579                         4579
# June                         4366  4366                         4366
# October                      4337  4337                         4337
# September                    4290  4290                         4290
# March                        4072  4072                         4072
# April                        4015  4015                         4015
# February                     3064  3064                         3064
# November                     2696  2696                         2696
# December                     2392  2392                         2392
# January                      2254  2254                         2254
#
#                     total_of_special_requests  reservation_status  \
# arrival_date_month
# August                                   5381                5381
# July                                     4782                4782
# May                                      4579                4579
# June                                     4366                4366
# October                                  4337                4337
# September                                4290                4290
# March                                    4072                4072
# April                                    4015                4015
# February                                 3064                3064
# November                                 2696                2696
# December                                 2392                2392
# January                                  2254                2254
#
#                     reservation_status_date
# arrival_date_month
# August                                 5381
# July                                   4782
# May                                    4579
# June                                   4366
# October                                4337
# September                              4290
# March                                  4072
# April                                  4015
# February                               3064
# November                               2696
# December                               2392
# January                                2254

# %%
df['people'] = df[['adults', 'children', 'babies']].sum(axis=1)

# %%
df[(df.hotel == 'City Hotel')]\
        .groupby('arrival_date_month')\
        .agg('sum')\
        .sort_values('people', ascending=False)['people']
# Out:
# arrival_date_month
# August       19401.0
# July         17203.0
# May          15464.0
# June         15116.0
# April        15101.0
# October      14133.0
# September    13961.0
# March        12333.0
# February      9376.0
# December      8145.0
# November      7524.0
# January       6721.0
# Name: people, dtype: float64

# %%
df[(df.hotel == 'City Hotel') & (df.reservation_status != 'Canceled')]\
        .groupby('arrival_date_month')\
        .agg('sum')\
        .sort_values('people', ascending=False)['people']
# Out:
# arrival_date_month
# August       11759.0
# July         10428.0
# May           8751.0
# June          8516.0
# April         8265.0
# October       8015.0
# September     7997.0
# March         7792.0
# February      5985.0
# December      4797.0
# November      4652.0
# January       4094.0
# Name: people, dtype: float64

# %% [markdown]
# Ответ: август

# %% [markdown]
# **Вопрос 10**
# Какой процент бронирований с типом питания BB (Bed&Breakfast) был сделан в City Hotel за все время?
# Ответ необходимо дать целым числом.

# %%
df[(df.hotel == 'City Hotel')].meal.value_counts(normalize=True) * 100
# Out:
# BB    78.539014
# SC    13.316526
# HB     8.088995
# FB     0.055465
# Name: meal, dtype: float64

# %% [markdown]
# Ответ: 79

# %%
df[(df.hotel == 'City Hotel') & (df.meal == 'BB')].shape[0] / df[(df.hotel == 'City Hotel')].shape[0] * 100
# Out:
# 78.53901424429598

# %%
 df[(df.hotel == 'City Hotel') & (df.reservation_status != 'Canceled')].meal.value_counts(normalize=True) * 100
# Out:
# BB    77.142372
# SC    14.349652
# HB     8.488885
# FB     0.019090
# Name: meal, dtype: float64

# %% [markdown]
# **Вопрос 11**
# (не по дата-сету)
# Андрей Озонов планирует заказать себе новые кроссовки и начать бегать. Вероятность того, что нужный товар доставят из магазина A, равна 0,85. Вероятность того, что этот товар доставят из магазина B, равна 0,90. Андрей Озонов заказал кроссовки сразу в обоих магазинах. Считая, что интернет-магазины работают независимо друг от друга, найдите вероятность того, что ни один магазин не доставит товар.
# Ответ необходимо дать в процентах с точностью до одного знака.

# %%
(1 - 0.85) * (1 - 0.9) * 100
# Out:
# 1.5

# %% [markdown]
# Ответ: 1,5

# %% [markdown]
# **Вопрос 12**
# (не по дата-сету)
# В таблице нижепредставлены данные о товарообороте компаний в месяц. Необходимо определить:
# - средний размер месячного товарооборота на одну фирму
# - моду и
# - медиану месячного товарооборота
# ![image.png](attachment:image.png)

# %% [markdown]
# ответ надо было выбрать из предложенных вариантов
# Ответ: 10,6, 7,5, 9,5

# %% [markdown]
# **Вопрос 13**
# (дополнительный вопрос без присвоения балла)
# Ниже дан график по данным о поездках на такси в районах Нью-Йорка. По оси X - название района, по оси Y - общая сумма чека.
# Проанализируйте график и напишите свои выводы в свободном формате. На занятии мы обсудим какие выводы можно сделать из этого графика:)
# Выпишите ответ себе в заметки, чтобы сверить свои выводы на занятии.
# ![image.png](attachment:image.png)

# %% [markdown]
# Если люди приезжают на такси на работу и уезжают на такси домой, то не должно быть распределение более равномерным? Распределения больше говорят о перемещении внутри района?
# В манхэттене и бруклине есть метро. В бронкс и квинз только концы веток доходят на окраинах районов. Это довлеющий фактор?
# Манхэтенцы - "белая кость", предпочитают жить и работать недалеко? Или метро решает?
# Квинз то ли большой, то ли ездит часто далеко. Спальный район "белых воротничков"? На работу срочно на такси, а возвращаются на электричках? Или внутри района ездят, за отсутствием метро?

# %%
dct = {1: 7, 2: 5, 3: 6}
dct
# Out:
# {1: 7, 2: 5, 3: 6}

# %%
dct[1] = 8
dct
# Out:
# {1: 8, 2: 5, 3: 6}

# %%
dct.pop(1)
dct
# Out:
# {2: 5, 3: 6}

# %%
dct[1] = 8
dct
# Out:
# {2: 5, 3: 6, 1: 8}

# %%
PRT
Resort Hotel: 48.57, City Hotel: 54.80
зима
69
57
47,3
27
лето
август
79
1,5
10,6, 7,5, 9,5
